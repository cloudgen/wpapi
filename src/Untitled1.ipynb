# %%
import requests
result = requests.get("https://data.weather.gov.hk/weatherAPI/opendata/weather.php?dataType=fnd&lang=en")
result.json()
# Out:
# {'generalSituation': 'A relatively dry replenishment of the northeast monsoon will reach the coast of Guangdong tomorrow morning. It will be brighter with cool mornings over the region in the following couple of days. Under the influence of a band of clouds, there will be one or two rain patches over Guangdong during the weekend. Another replenishment of the monsoon will reach southern China next Monday, it will be windier over the coastal areas midweek next week.',
#  'weatherForecast': [{'forecastDate': '20240110',
#    'week': 'Wednesday',
#    'forecastWind': 'Light winds force 2, becoming northeast force 3 to 4, force 5 offshore later.',
#    'forecastWeather': 'Mainly cloudy. Visibility relatively low in some areas at first. Dry with sunny periods during the day.',
#    'forecastMaxtemp': {'value': 24, 'unit': 'C'},
#    'forecastMintemp': {'value': 18, 'unit': 'C'},
#    'forecastMaxrh': {'value': 85, 'unit': 'percent'},
#    'forecastMinrh': {'value': 55, 'unit': 'percent'},
# ...
